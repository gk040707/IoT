# %% [markdown]
# <a href="https://colab.research.google.com/github/gk040707/IoT/blob/main/%ED%99%98%EA%B2%BD%EC%84%BC%EC%84%9C%EA%B0%92_%3E_MQTT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install paho-mqtt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.9/66.9 kB 1.4 MB/s eta 0:00:00
# ...

# %%
import paho.mqtt.client as mqtt

def on_connect(client, userdata, flags, reason_code, properties):
    print(f"Connected with result code {reason_code}")
    client.subscribe("connectware/indoor/data/#")

def on_message(client, userdata, msg):
    print(msg.topic, msg.payload.decode('utf8'))

client = mqtt.Client(mqtt.CallbackAPIVersion.VERSION2)
client.on_connect = on_connect
client.on_message = on_message

client.connect("damoa.io", 1883, 60)
client.loop_forever()
# Out:
# Connected with result code Success
# connectware/indoor/data/1502 {"dust":"6,8","co2":"1197","bme680":"29.25,29.47,1316831,100666,55.09","time":"2024-04-04 17:26:29", "serial":2684, "ip":"203.255.190.49"}
# connectware/indoor/data/1501 {"dust":"8,9","co2":"503","bme680":"27.83,32.19,796800,100616,59.20","time":"2024-04-04 17:26:28", "serial":7245, "ip":"203.255.190.49"}
# connectware/indoor/data/1503 {"dust":"2,2","co2":"1085","bme680":"28.50,31.39,601208,100624,58.53","time":"2024-04-04 17:26:29", "serial":2693, "ip":"203.255.190.49"}
# connectware/indoor/data/1502 {"dust":"6,8","co2":"1197","bme680":"29.25,29.46,1324701,100666,55.01","time":"2024-04-04 17:26:30", "serial":2685, "ip":"203.255.190.49"}
# connectware/indoor/data/1501 {"dust":"9,10","co2":"499","bme680":"27.83,32.19,797746,100615,59.20","time":"2024-04-04 17:26:29", "serial":7246, "ip":"203.255.190.49"}
# ...
