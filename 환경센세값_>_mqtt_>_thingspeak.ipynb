# %% [markdown]
# <a href="https://colab.research.google.com/github/gk040707/IoT/blob/main/%ED%99%98%EA%B2%BD%EC%84%BC%EC%84%B8%EA%B0%92_%3E_mqtt_%3E_thingspeak.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install paho-mqtt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.9/66.9 kB 1.3 MB/s eta 0:00:00
# ...

# %%
import json
import requests
n=0

def doit(topic, payload):
  global n
  print(topic, payload)
  j=json.loads(payload)
  #print(j['co2'])
  url='https://api.thingspeak.com/update?api_key=RJY0FT6WT2M5RUWL'
  url +='&field1='+j['co2']
  url +='&field2='+j['bme680'].split(',')[0]
  if n>15:
    r=requests.get(url)
    print(url, r.text)
    n=0
  n+=1

# %%
import paho.mqtt.client as mqtt

def on_connect(client, userdata, flags, reason_code, properties):
    print(f"Connected with result code {reason_code}")
    client.subscribe("connectware/indoor/data/1501")

def on_message(client, userdata, msg):
    doit(msg.topic, msg.payload.decode('utf8'))

client = mqtt.Client(mqtt.CallbackAPIVersion.VERSION2)
client.on_connect = on_connect
client.on_message = on_message

client.connect("damoa.io", 1883, 60)
client.loop_forever()
# Out:
# Connected with result code Success
# connectware/indoor/data/1501 {"dust":"7,8","co2":"399","bme680":"28.00,31.96,803945,100636,57.52","time":"2024-04-04 17:37:49", "serial":7926, "ip":"203.255.190.49"}
# connectware/indoor/data/1501 {"dust":"7,7","co2":"399","bme680":"28.00,31.96,806838,100636,57.44","time":"2024-04-04 17:37:50", "serial":7927, "ip":"203.255.190.49"}
# connectware/indoor/data/1501 {"dust":"7,7","co2":"399","bme680":"28.00,31.97,804907,100636,57.52","time":"2024-04-04 17:37:51", "serial":7928, "ip":"203.255.190.49"}
# connectware/indoor/data/1501 {"dust":"8,8","co2":"399","bme680":"28.00,31.96,802027,100635,57.52","time":"2024-04-04 17:37:52", "serial":7929, "ip":"203.255.190.49"}
# connectware/indoor/data/1501 {"dust":"8,8","co2":"399","bme680":"28.00,31.95,802506,100635,57.52","time":"2024-04-04 17:37:53", "serial":7930, "ip":"203.255.190.49"}
# ...
